# %%
#importing required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data = pd.read_csv('Train_pjb2QcD.csv') 
train_data.head()
# Out:
#            ID  Office_PIN Application_Receipt_Date  Applicant_City_PIN  \
# 0  FIN1000001      842001                4/16/2007            844120.0
# 1  FIN1000002      842001                4/16/2007            844111.0
# 2  FIN1000003      800001                4/16/2007            844101.0
# 3  FIN1000004      814112                4/16/2007            814112.0
# 4  FIN1000005      814112                4/16/2007            815351.0
#
#   Applicant_Gender Applicant_BirthDate Applicant_Marital_Status  \
# 0                M          12/19/1971                        M
# 1                M           2/17/1983                        S
# 2                M           1/16/1966                        M
# 3                M            2/3/1988                        S
# 4                M            7/4/1985                        M
#
#   Applicant_Occupation Applicant_Qualification Manager_DOJ        ...         \
# 0               Others                Graduate  11/10/2005        ...
# ...

# %%
y_train = train_data['Business_Sourced']
train_data = train_data.drop('Business_Sourced', axis=1)

# %%
test_data = pd.read_csv('Test_wyCirpO.csv')
test_data.head()
# Out:
#            ID  Office_PIN Application_Receipt_Date  Applicant_City_PIN  \
# 0  FIN1009528      284001                 7/2/2008            284001.0
# 1  FIN1009529      800001                 7/2/2008            800026.0
# 2  FIN1009530      800001                 7/2/2008                 NaN
# 3  FIN1009531      800001                 7/2/2008            844112.0
# 4  FIN1009532      533101                 7/2/2008            533102.0
#
#   Applicant_Gender Applicant_BirthDate Applicant_Marital_Status  \
# 0                M            8/5/1982                        S
# 1                M           3/11/1968                        M
# 2                M          12/16/1984                        S
# 3                M            6/7/1971                        S
# 4                M           7/22/1978                        S
#
#   Applicant_Occupation             Applicant_Qualification Manager_DOJ  \
# 0             Salaried                            Graduate   5/26/2008
# ...

# %%
#extract id's

ids = test_data['ID']

# %%
x_len = len(train_data)
all_data = pd.concat([train_data, test_data])

# %%
all_data = pd.get_dummies(all_data)

# %%
all_data.fillna(0,inplace=True)

# %%
#split dataset into train and test datasets

x_train = all_data.iloc[:x_len,:]
test_data = all_data.iloc[x_len:,:]

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x_train,y_train)
# Out:
# C:\Users\pavani singam shetty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
pred = logreg.predict(test_data)

# %%
logreg.score(x_train,y_train)
# Out:
# 0.6569749134040097

# %%
#concat id's and predicted values
df1 = pd.DataFrame(ids)
df2['Business_Sourced'] = pd.DataFrame(pred)

pred_outcome = pd.concat([df1, df2['Business_Sourced']], axis=1)
print(pred_outcome)
# Out:
#               ID  Business_Sourced
# 0     FIN1009528                 0
# 1     FIN1009529                 0
# 2     FIN1009530                 0
# 3     FIN1009531                 0
# 4     FIN1009532                 0
# 5     FIN1009533                 0
# 6     FIN1009534                 0
# 7     FIN1009535                 0
# 8     FIN1009536                 0
# 9     FIN1009537                 0
# 10    FIN1009538                 0
# 11    FIN1009539                 0
# 12    FIN1009540                 0
# 13    FIN1009541                 0
# 14    FIN1009542                 0
# 15    FIN1009543                 0
# 16    FIN1009544                 0
# 17    FIN1009545                 0
# 18    FIN1009546                 0
# 19    FIN1009547                 0
# 20    FIN1009548                 0
# 21    FIN1009549                 0
# 22    FIN1009550                 0
# 23    FIN1009551                 0
# 24    FIN1009552                 0
# 25    FIN1009553                 0
# ...

# %%
#exporting dataframe to csv file

export_csv = pred_outcome.to_csv (r'C:\Users\pavani singam shetty\datascience\logistic_reg.csv', index = None, header=True)
